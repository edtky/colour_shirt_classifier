# %% [markdown]
# # Download training images from Google
#
# --------
#
# Use googleimagedownload to scrap training images from Google. (https://github.com/hardikvasa/google-images-download)
#
# Keywords: "red shirt", "blue shirt", "green shirt"
# Limit: 700 images
# Format: jpg
# Size: Medium
#
# About 400 images for each class were found matching the above criterias
#
# Post-process: Absolutely required to get good training. Remove:
# - irrelevant images
# - images with mislabled colours
# - corrupted images
#
# **Important Note:** If you are downloading more than 100 images, you need to install the appropriate chromedriver (with Selenium). See troubleshooting section of hardivasa's Github repo.

# %%
# !googleimagesdownload --keywords "red shirt" --limit 700 --format jpg --size medium --chromedriver ./chromedriver
# Out:
# Item no.: 1 --> Item name = red shirt
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Completed Image ====> 1. 40-nl-sofh06-rean15q-rose-redred-blackberrys-original-imaf6gg2su64smny.jpeg
# Completed Image ====> 2. img_9167_5.jpg
# Completed Image ====> 3. bfshtpc501rd-being-fab-40-original-imaecvnx9swvsvp5.jpeg
# Completed Image ====> 4. 71nddkjmkbl._sr500,500_.jpg
# Completed Image ====> 5. redshirt.0.jpg
# Completed Image ====> 6. red-shirt.jpg
# Completed Image ====> 7. 85181-250173-large.jpg
# Completed Image ====> 8. dsc_3669-500x500.jpg
# Completed Image ====> 9. img_9468_5.jpg
# Completed Image ====> 10. 173082-435814-large.jpg
# Completed Image ====> 11. plain-t-shirt-red-1-800x800.jpg
# Completed Image ====> 12. 71e63p+jenl._sr500,500_.jpg
# Completed Image ====> 13. 268602-1069000-large.jpg
# Completed Image ====> 14. temp2.0x0.jpg
# ...

# %%
# !googleimagesdownload --keywords "blue shirt" --limit 700 --format jpg --size medium --chromedriver ./chromedriver
# Out:
# Item no.: 1 --> Item name = blue shirt
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Completed Image ====> 1. 46-bfrybluesht02-being-fab-original-imaekjr8ymhnxznp.jpeg
# Completed Image ====> 2. l-cc201-skyblue-dennis-lingo-original-imaex2kgzrrppawh.jpeg
# Completed Image ====> 3. ossm_navy-royale_website_rgb_clean_4.jpg
# Completed Image ====> 4. m-kpc-38lg-gy-ob-koolpals-original-imae5kubs6wyeqns.jpeg
# Completed Image ====> 5. 51rfi3sl6el.jpg
# Completed Image ====> 6. 199775-614183-large.jpg
# Completed Image ====> 7. 71iv3lopvel._ux522_.jpg
# Completed Image ====> 8. 277916-1449997-large.jpg
# Completed Image ====> 9. levis-royal-blue-casual-shirt.jpg
# Completed Image ====> 10. bfshtpc501skblu-being-fab-46-original-imaecsye3vyfkaag.jpeg
# Completed Image ====> 11. 201809_sep2_m_shirtfit_imgdefault.jpg
# Completed Image ====> 12. 278474-1147459-large.jpg
# ...

# %%
# !googleimagesdownload --keywords "green shirt" --limit 700 --format jpg --size medium --chromedriver ./chromedriver
# Out:
# Item no.: 1 --> Item name = green shirt
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Completed Image ====> 1. ossm_evergreen_website_rgb_clean_4.jpg
# Completed Image ====> 2. apple_front.jpg
# Completed Image ====> 3. rcsh-rg-bg-suspense-l-original-imaeexqucy2hysxh.jpeg
# Completed Image ====> 4. m_5b85c83b6197459cccc1fcaa.jpeg
# Completed Image ====> 5. m-521rmdeepteal-french-connection-original-imaf5zsafjkrwn6q.jpeg
# Completed Image ====> 6. guest_ab0a7ed2-4f4a-4477-9542-5f62bdf3a7b9?wid=488&hei=488&fmt=pjpeg.jpg
# URLError on an image...trying next one... Error: <urlopen error [Errno 8] nodename nor servname provided, or not known>
# Completed Image ====> 7. electric_green_1b0be7d9-6a11-41b4-967b-94083c9813d0_large.jpg
# Completed Image ====> 8. ff
# Completed Image ====> 9. s-cc201-green-dennis-lingo-original-imaf6mfmuabx2yws.jpeg
# Completed Image ====> 10. mens-mint-color-shirt-4532.jpg
# ...
